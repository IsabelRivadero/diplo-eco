# %% [markdown]
# ##PRÁCTICO 1

# %% [markdown]
# Declarar una variable llamada poblacion con valor 1000000

# %%
poblacion= 1000000
poblacion
type(poblacion)
# Out:
# int

# %% [markdown]
# Declarar la variable area con valor 300000

# %%
area= 300000
area
# Out:
# 300000

# %% [markdown]
# Calcular Densidad pobacional

# %%
densidad = poblacion/area
densidad
# Out:
# 3.3333333333333335

# %% [markdown]
# Declarar variable provincia igual a "Buenos Aires"

# %%
provincia= "Cordoba"
provincia
# Out:
# 'Cordoba'

# %% [markdown]
# Crear variable es_patagonia igual a False

# %%
es_patagonia= False
es_patagonia
# Out:
# False

# %% [markdown]
# Verificar qué tipos de variables son las anteriores

# %%
print(type("Cordoba")), print(type("es_patagonia"))
# Out:
# <class 'str'>
# <class 'str'>
# (None, None)

# %% [markdown]
# Declarar la variable doble_poblacion
#
# Print doble_poblacion

# %%
doble_poblacion=poblacion*2
print(doble_poblacion)
type(doble_poblacion)
# Out:
# 2000000
# int

# %% [markdown]
# Crear una variable doble_provincia
#
# Print doble_provincia

# %%
doble_provincia=provincia*2
print(doble_provincia)
type(doble_provincia)
# Out:
# CordobaCordoba
# str

# %% [markdown]
# Escribir en la consola "La Provincia de <provincia> tiene una población de <poblacion> habitantes"

# %%
print("La Provincia de <provincia> tiene una poblacion de <poblacion> habitantes")
# Out:
# La Provincia de <provincia> tiene una poblacion de <poblacion> habitantes

# %% [markdown]
# Definicion de la variable pi_string  ( $\pi$ )- Nada que ver con la temática pero es para ver opciones de cambiar el formato al imporimir.

# %%
import math
pi_string= '{:.2f}'.format(math.pi)  
print(pi_string)
type(pi_string)
# Out:
# 3.14
# str

# %%
pi= (math.pi)  
print(pi)
type(pi)
# Out:
# 3.141592653589793
# float

# %% [markdown]
# Convertir pi_string en pi_float

# %%
pi_float = float(pi_string)
print(pi)
type(pi)
# Out:
# 3.141592653589793
# float

# %% [markdown]
# Convertir pi_float en pi_int

# %%
pi_int = int(pi_float)
print(pi_int)
type(pi_int)
# Out:
# 3
# int

# %% [markdown]
# # PRÁCTICO 2

# %% [markdown]
# Vamos a definir las superficies de cada provincia en Km2
# Fuente: [IGN](https://www.ign.gob.ar/NuestrasActividades/Geografia/DatosArgentina/DivisionPolitica)
#
# Ciudad Autónoma de Buenos Aires	**200**
# Córdoba	**165321**
# Corrientes **88199**
# Entre Ríos **78781**
# Formosa **72066**
# Jujuy	**53219**
# La Pampa	**143440**
# La Rioja	**89680**
# Mendoza	**148827**
# Misiones	**29801**
# Neuquén	**94078**
# Salta	**155488**
# San Luis	**76748**
# San Juan **89651**

# %%
caba=200
cordoba=165321
corrientes=88199
entre_rios= 78781
formosa =72066
jujuy=	53219
la_pampa=	143440
la_rioja=	89680
mendoza=	148827
misiones=	29801
neuquen=	94078
salta=	155488
san_luis=	76748
san_juan= 89651

# %% [markdown]
# Crear una lista de áreas

# %%
areas = [caba, cordoba, corrientes, entre_rios, formosa, jujuy, la_pampa, la_rioja, mendoza, misiones, neuquen, salta, san_luis,san_juan]
print(areas)
type(areas)
# Out:
# [200, 165321, 88199, 78781, 72066, 53219, 143440, 89680, 148827, 29801, 94078, 155488, 76748, 89651]
# list

# %% [markdown]
# Completar lista de áreas con los nombres

# %%
nombre_areas = ["Ciudad Autónoma de Buenos Aires", 
  "Córdoba",	
  "Corrientes",
  "Entre Ríos",
  "Formosa", 
  "Jujuy", 
  "La Pampa",
  "La Rioja",
  "Mendoza",
  "Misiones", 
  "Neuquén", 
  "Salta", 
  "San Luis",
  "San Juan"]
print(nombre_areas)
type(nombre_areas)
# Out:
# ['Ciudad Autónoma de Buenos Aires', 'Córdoba', 'Corrientes', 'Entre Ríos', 'Formosa', 'Jujuy', 'La Pampa', 'La Rioja', 'Mendoza', 'Misiones', 'Neuquén', 'Salta', 'San Luis', 'San Juan']
# list

# %% [markdown]
# Información de estas provincias de Argentina como una lista

# %%
argentina = [["Ciudad Autónoma de Buenos Aires", caba], 
  ["Córdoba", cordoba],	
  ["Corrientes", corrientes],
  ["Entre Ríos", entre_rios],
  ["Formosa", formosa],
  ["Jujuy", jujuy],
  ["La Pampa", la_pampa],
  ["La Rioja", la_rioja],
  ["Mendoza", mendoza],
  ["Misiones", misiones],
  ["Neuquén", neuquen],
  ["Salta", salta],
  ["San Luis", san_luis],
  ["San Juan", san_juan]]

print(argentina)
type(argentina)
# Out:
# [['Ciudad Autónoma de Buenos Aires', 200], ['Córdoba', 165321], ['Corrientes', 88199], ['Entre Ríos', 78781], ['Formosa', 72066], ['Jujuy', 53219], ['La Pampa', 143440], ['La Rioja', 89680], ['Mendoza', 148827], ['Misiones', 29801], ['Neuquén', 94078], ['Salta', 155488], ['San Luis', 76748], ['San Juan', 89651]]
# list

# %% [markdown]
# # PRÁCTICO 3

# %%
#recuperamos la lista de areas
print(areas)
# Out:
# [200, 165321, 88199, 78781, 72066, 53219, 143440, 89680, 148827, 29801, 94078, 155488, 76748, 89651]

# %% [markdown]
# Identificar el terecer elemento de la lista areas y el último elemento

# %%
print(areas[1])
print(areas[-1])
# Out:
# 165321
# 89651

# %% [markdown]
# A partir de la lista *areas* crear la variable region_cuyo y obtener el total de superfice en km2 de esa región:
#
# ---

# %%
area_region_cuyo = la_rioja+ mendoza+ san_luis + san_juan
  # desde la lista sería:
area_region_cuyo = areas[7]+areas[8]+areas[12]+areas[13]
print(area_region_cuyo) 
type(area_region_cuyo)
# Out:
# 404906
# int

# %% [markdown]
# # PRÁCTICO 4

# %% [markdown]
# Agregar al final de la lista *areas* las provincias y  superficies de Buenos Aires = 307571  y de Santa Fé= 13007, en ese orden.
# use función .append

# %%
#declaremos las varaibles Santa Fe y Córdoba
santa_fe=13007
bs_as=307571
# agregamos a la lista "areas" los datos de las dos provincias, es decir agregamos a la lista dos elemntos nuevos
areas.append(santa_fe) #cuidado!! si corre reitaradmante esta linea agragará  a la lista el dato cada vez que la corra 
areas.append(bs_as)
print(areas)
# Out:
# [200, 165321, 88199, 78781, 72066, 53219, 143440, 89680, 148827, 29801, 94078, 155488, 76748, 89651, 13007, 307571]

# %% [markdown]
# Corregir en la lista areas el dato de la superficie de Santa Fe= 133007

# %%
# primero vemos cuál es la ubicación del dato erróneo en la lista
#areas.index(santa_fe)

# %%
#reempalzamos el dato en la posición 14
areas[14]=133007
areas
# Out:
# [200,
#  165321,
#  88199,
#  78781,
#  72066,
#  53219,
#  143440,
#  89680,
#  148827,
#  29801,
#  94078,
#  155488,
#  76748,
#  89651,
#  133007,
#  307571]

# %% [markdown]
# la corrección se hizo sólo sobre la lista areas, y el objeto o variable santa_fe??

# %%
santa_fe
# Out:
# 13007

# %%
#la corrección sólo se hizo sobre la lista área, no sobre el objeto a partir de cual se construyó antes esa lista.
santa_fe=133007

# %% [markdown]
# Agregar como segundo y tercer elmentos de la lista *nombre_areas* las provincias y  Buenos Aires  y  Santa Fé.
# use función .extend creando previamente otra lista

# %%
nombre_areas_nvas=["Buenos Aires","Santa Fe"]
nombre_areas.extend(nombre_areas_nvas)
nombre_areas
# Out:
# ['Ciudad Autónoma de Buenos Aires',
#  'Córdoba',
#  'Corrientes',
#  'Entre Ríos',
#  'Formosa',
#  'Jujuy',
#  'La Pampa',
#  'La Rioja',
#  'Mendoza',
#  'Misiones',
#  'Neuquén',
#  'Salta',
#  'San Luis',
#  'San Juan',
#  'Buenos Aires',
#  'Santa Fe']

# %% [markdown]
# Verificar que la cantidad de elementos de las listas areas y nombres_areas sean iguales

# %%
len(nombre_areas)==len(areas)
# Out:
# True

# %% [markdown]
# Crear una copia de la lista nombre_areas, en el objeto nombre_areas_copia

# %%
nombre_areas_copia=list(nombre_areas)
nombre_areas_copia
# Out:
# ['Ciudad Autónoma de Buenos Aires',
#  'Córdoba',
#  'Corrientes',
#  'Entre Ríos',
#  'Formosa',
#  'Jujuy',
#  'La Pampa',
#  'La Rioja',
#  'Mendoza',
#  'Misiones',
#  'Neuquén',
#  'Salta',
#  'San Luis',
#  'San Juan',
#  'Buenos Aires',
#  'Santa Fe']

# %% [markdown]
# Ordenar alfabéticamente los elementos de la lista copia

# %%
nombre_areas_copia=sorted(nombre_areas_copia)
nombre_areas_copia
# Out:
# ['Buenos Aires',
#  'Ciudad Autónoma de Buenos Aires',
#  'Corrientes',
#  'Córdoba',
#  'Entre Ríos',
#  'Formosa',
#  'Jujuy',
#  'La Pampa',
#  'La Rioja',
#  'Mendoza',
#  'Misiones',
#  'Neuquén',
#  'Salta',
#  'San Juan',
#  'San Luis',
#  'Santa Fe']

# %% [markdown]
# Verificar si en la lista nombres_areas se encuentra la provincia "Rio Negro" ( use *in*)

# %%
print("Rio Negro" in nombre_areas)
# Out:
# False

# %% [markdown]
# Reescribir el nombre de la Ciudad Autónoma de Buenos Aires" como Caba

# %%
# Usar upper() en nombres_areas
nombre_areas.index("Ciudad Autónoma de Buenos Aires")
# Out:
# 0

# %%
#reescribimos el nombre en la lista nombre_areas
nombre_areas[0]="Caba"
nombre_areas
# Out:
# ['Caba',
#  'Córdoba',
#  'Corrientes',
#  'Entre Ríos',
#  'Formosa',
#  'Jujuy',
#  'La Pampa',
#  'La Rioja',
#  'Mendoza',
#  'Misiones',
#  'Neuquén',
#  'Salta',
#  'San Luis',
#  'San Juan',
#  'Buenos Aires',
#  'Santa Fe']

# %% [markdown]
# Agregar a nombre_areas un elemento en la posición 2 (tercer elemento) que sea igual a "Tierra del Fuego". Use .insert

# %%
# Recordar que .insert requiere dos argumentos el primero es la posición en la lista y el segundo el elemento a agregar. 
print(type(nombre_areas))
nombre_areas.insert(2,'Tierra del Fuego')
print(nombre_areas)
# Out:
# <class 'list'>
# ['Caba', 'Córdoba', 'Tierra del Fuego', 'Corrientes', 'Entre Ríos', 'Formosa', 'Jujuy', 'La Pampa', 'La Rioja', 'Mendoza', 'Misiones', 'Neuquén', 'Salta', 'San Luis', 'San Juan', 'Buenos Aires', 'Santa Fe']

# %% [markdown]
# Ahora borrar de la lista nombre_areas el elemento "Tierra del Fuego" con la función .remove

# %%
nombre_areas.remove('Tierra del Fuego')
nombre_areas
# Out:
# ['Caba',
#  'Córdoba',
#  'Corrientes',
#  'Entre Ríos',
#  'Formosa',
#  'Jujuy',
#  'La Pampa',
#  'La Rioja',
#  'Mendoza',
#  'Misiones',
#  'Neuquén',
#  'Salta',
#  'San Luis',
#  'San Juan',
#  'Buenos Aires',
#  'Santa Fe']
