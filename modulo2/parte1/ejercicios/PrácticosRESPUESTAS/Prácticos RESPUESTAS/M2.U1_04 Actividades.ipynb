# %% [markdown]
# ![img](https://drive.google.com/uc?export=view&id=1kgX98Ziw9LzgBCT2BxChttfrTcBltLej)

# %% [markdown]
# # PRÁCTICO 13

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %% [markdown]
# Importar la [**serie temporal** ](http://www.bcra.gov.ar/PublicacionesEstadisticas/Principales_variables_datos.asp)del archivo disponible en:
# https://drive.google.com/file/d/1TGqFDXCPVrJDquKJuz9ec3aPRRxqSUwX/view?usp=sharing
#
# Reservas Internacionales del BCRA (en millones de dólares - cifras provisorias sujetas a cambio de valuación)

# %%
 url="https://drive.google.com/file/d/1TGqFDXCPVrJDquKJuz9ec3aPRRxqSUwX/view?usp=sharing"
path = 'https://drive.google.com/uc?export=download&id=' + url.split('/')[-2]
df_reservas=pd.read_csv(path, encoding="latin-1",sep=';')
df_reservas.head()
# Out:
#       Fecha   Valor
# 0  3/1/2012  46.231
# 1  4/1/2012  46.446
# 2  5/1/2012  46.440
# 3  6/1/2012  46.426
# 4  9/1/2012  46.222

# %% [markdown]
#  * Utilizar el método sort_index(inplace=True) para ordenar la serie temporal
#  * Utilizar el argumento parse_dates para convertir la primera columna del archivo en una fecha
#  * Utilizar el argumento index_col para convertir la primera columna del archivo en índice
#  * Utilizar el nombre de variable df_reservas

# %%
df_reservas.sort_index(inplace=True)
df_reservas.head()
# Out:
#       Fecha   Valor
# 0  3/1/2012  46.231
# 1  4/1/2012  46.446
# 2  5/1/2012  46.440
# 3  6/1/2012  46.426
# 4  9/1/2012  46.222

# %%
df_reservas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2330 entries, 0 to 2329
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fecha   2330 non-null   object
#  1   Valor   2330 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 36.5+ KB

# %% [markdown]
# Descriptiva básica

# %%
df_reservas.describe(include='all', datetime_is_numeric=False)
# Out:
#             Fecha        Valor
# count        2330  2330.000000
# unique       2330          NaN
# top     24/1/2012          NaN
# freq            1          NaN
# mean          NaN    42.513221
# std           NaN    11.195801
# min           NaN    24.141000
# 25%           NaN    33.133250
# 50%           NaN    42.599500
# 75%           NaN    48.111750
# max           NaN    77.481000

# %% [markdown]
# Graficar la evolución histórica de la serie
#  * Importar matplotlib
#  * Visualizar la serie temporal completa
#  * Agregarle el título "Evolución Historica de las Reservas del BCRA"
#  * Agregarle una etiqueta a eje y: "Millones de USD"
#  * Usar style=r para cambiar el color de la linea a rojo

# %%
df_reservas.plot(title="Evolución Historica de las Reservas del BCRA", style="r")
plt.ylabel("Millones de USD")
plt.show()
